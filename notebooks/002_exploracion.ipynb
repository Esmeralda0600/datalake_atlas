# %%
import glob
import xarray as xr
import pandas as pd

# %%
files = sorted(glob.glob("../datalake/001_raw/ECMWF_utci_2023*_v1.1_con.nc"))

files_total = len(files)
print(f"total archivos: {files_total}")
# Out:
# total archivos: 31

# %%
#annual = "../data/002_intermediate/ECMWF_utci_2023_anual.nc"
#conca_annual = xr.open_mfdataset(unique_files, combine='nested', concat_dim='time', parallel=False, chunks={'time': 24})
#conca_annual.to_netcdf(annual)
annual = "../data/002_trusted/ECMWF_utci_2023_v1.nc"

conca_annual = xr.open_mfdataset(files, combine='nested', concat_dim='time', parallel=False, chunks={'time': 24})

config_compresion = {
    "utci": {
        "zlib": True,       
        "complevel": 4      
    }
}

conca_annual.to_netcdf(annual, encoding=config_compresion)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\atlas\Documents\datalake\.venv\Lib\site-packages\xarray\backends\file_manager.py:219, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     218 try:
# --> 219     file = self._cache[self._key]
#     220 except KeyError:
#
# File c:\Users\atlas\Documents\datalake\.venv\Lib\site-packages\xarray\backends\lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('c:\\Users\\atlas\\Documents\\datalake\\data\\002_trusted\\ECMWF_utci_2023_anual_v1.nc',), 'a', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False)), 'fcac5df6-2a52-4c86-9964-e661715d21c4']
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
df_fp = xr.open_dataset(annual, chunks={'time': 24}) 
df_final = df_fp['utci'].isel(lat=0, lon=0).to_dataframe()
print(df_final.head(72))
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
